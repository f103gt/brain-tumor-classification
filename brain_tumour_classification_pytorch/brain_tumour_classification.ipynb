# %%
import os
import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.models as models
from torch.utils.data import DataLoader, random_split
from torchvision.datasets import ImageFolder
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import precision_score, recall_score, f1_score

CONFIG = {
    "IMAGES_DIR_TRAINING": "./Training",
    "IMAGES_DIR_TESTING": "./Testing",
    "CLASSES": ["glioma", "meningioma", "notumor", "pituitary"],
    "TRAIN_RATIO": 0.8,
    "VALIDATE_RATIO": 0.2,
    "BATCH_SIZE": 8,
    "IMAGE_SIZE": 224,
    "IMAGE_DIVISION": 255.0,
    "N_EPOCHS": 50,
    "LEARNING_RATE": 3e-5,
    "NUM_CLASSES": 4,
}

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Num GPUs Available:", torch.cuda.device_count())

train_transform = transforms.Compose([
    transforms.Resize((CONFIG["IMAGE_SIZE"], CONFIG["IMAGE_SIZE"])),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.3),
    transforms.RandomRotation(20),
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
    transforms.ColorJitter(brightness=0.3, contrast=0.3),
    transforms.RandomAdjustSharpness(sharpness_factor=2),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

val_transform = transforms.Compose([
    transforms.Resize((CONFIG["IMAGE_SIZE"], CONFIG["IMAGE_SIZE"])),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

train_dataset = ImageFolder(CONFIG["IMAGES_DIR_TRAINING"], transform=train_transform)
train_size = int(CONFIG["TRAIN_RATIO"] * len(train_dataset))
val_size = len(train_dataset) - train_size
train_dataset, val_dataset = random_split(train_dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=CONFIG["BATCH_SIZE"], shuffle=True, num_workers=0, pin_memory=False)
val_loader = DataLoader(val_dataset, batch_size=CONFIG["BATCH_SIZE"], shuffle=False, num_workers=0, pin_memory=False)

model = models.efficientnet_b0(weights=models.EfficientNet_B0_Weights.IMAGENET1K_V1)
model.classifier = nn.Sequential(
    nn.Linear(model.classifier[1].in_features, 256),
    nn.ReLU(),
    nn.Linear(256, CONFIG["NUM_CLASSES"]),
)
model = model.to(device)

for param in list(model.features.parameters())[:-50]:
    param.requires_grad = False

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adamax(model.parameters(), lr=CONFIG["LEARNING_RATE"])

for epoch in range(CONFIG["N_EPOCHS"]):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for images, labels in train_loader:
        images, labels = images.to(device, non_blocking=True), labels.to(device, non_blocking=True)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        correct += predicted.eq(labels).sum().item()
        total += labels.size(0)

    train_loss = running_loss / len(train_loader)
    train_acc = 100. * correct / total

    model.eval()
    val_loss = 0.0
    correct_val = 0
    total_val = 0
    all_preds = []
    all_labels = []

    class_correct = {i: 0 for i in range(CONFIG["NUM_CLASSES"])}
    class_total = {i: 0 for i in range(CONFIG["NUM_CLASSES"])}
    class_pred_counts = {i: {j: 0 for j in range(CONFIG["NUM_CLASSES"])} for i in range(CONFIG["NUM_CLASSES"])}

    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device, non_blocking=True), labels.to(device, non_blocking=True)

            outputs = model(images)

            loss = criterion(outputs, labels)
            val_loss += loss.item()

            _, predicted = torch.max(outputs, 1)
            correct_val += predicted.eq(labels).sum().item()
            total_val += labels.size(0)

            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

            for true, pred in zip(labels.cpu().numpy(), predicted.cpu().numpy()):
                class_total[true] += 1
                class_pred_counts[pred][true] += 1
                if true == pred:
                    class_correct[true] += 1

    val_loss /= len(val_loader)
    val_acc = 100. * correct_val / total_val

    precision = precision_score(all_labels, all_preds, average="weighted")
    recall = recall_score(all_labels, all_preds, average="weighted")
    f1 = f1_score(all_labels, all_preds, average="weighted")

    class_precision = {}
    for class_idx in range(CONFIG["NUM_CLASSES"]):
        total_preds_for_class = sum(class_pred_counts[class_idx].values())
        if total_preds_for_class > 0:
            class_precision[class_idx] = class_pred_counts[class_idx][class_idx] / total_preds_for_class
        else:
            class_precision[class_idx] = 0.0

    print(f"Epoch {epoch+1}/{CONFIG['N_EPOCHS']} - "
          f"Train Loss: {train_loss:.4f} - Train Acc: {train_acc:.2f}% - "
          f"Val Loss: {val_loss:.4f} - Val Acc: {val_acc:.2f}% - "
          f"Precision: {precision:.4f} - Recall: {recall:.4f} - F1-score: {f1:.4f}")
    
    print("\nClass-wise Validation Metrics:")
    for i in range(CONFIG["NUM_CLASSES"]):
        if class_total[i] > 0:
            print(f"{CONFIG['CLASSES'][i]}:")
            print(f"  Precision: {class_precision[i]:.4f}")
            print(f"  Recall:    {class_correct[i]/class_total[i]:.4f}")
            print(f"  Samples:   {class_total[i]}")
    print("\n" + "="*80 + "\n")

def count_images_per_class(directory):
    class_counts = {}
    for class_name in os.listdir(directory):
        class_path = os.path.join(directory, class_name)
        if os.path.isdir(class_path):
            class_counts[class_name] = len(os.listdir(class_path))
    return class_counts

class_counts = count_images_per_class(CONFIG["IMAGES_DIR_TRAINING"])
class_labels = CONFIG["CLASSES"]
class_indices = {class_name: i for i, class_name in enumerate(class_labels)}

class_weight = compute_class_weight(
    class_weight='balanced',
    classes=np.arange(len(class_labels)),
    y=np.concatenate([np.full(count, class_indices[class_name]) for class_name, count in class_counts.items()])
)

class_weight_dict = {i: weight for i, weight in enumerate(class_weight)}
print("Class Weights:", class_weight_dict)
# Out:
# Num GPUs Available: 1
# Epoch 1/50 - Train Loss: 1.1072 - Train Acc: 69.34% - Val Loss: 0.7304 - Val Acc: 82.59% - Precision: 0.8305 - Recall: 0.8259 - F1-score: 0.8134
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9121
#   Recall:    0.8321
#   Samples:   262
# meningioma:
#   Precision: 0.8025
#   Recall:    0.4773
#   Samples:   264
# notumor:
#   Precision: 0.8643
#   Recall:    0.9689
#   Samples:   322
# pituitary:
#   Precision: 0.7461
#   Recall:    0.9763
#   Samples:   295
#
# ================================================================================
#
# Epoch 2/50 - Train Loss: 0.6609 - Train Acc: 78.88% - Val Loss: 0.4427 - Val Acc: 87.31% - Precision: 0.8716 - Recall: 0.8731 - F1-score: 0.8714
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9083
#   Recall:    0.8321
#   Samples:   262
# meningioma:
#   Precision: 0.7702
#   Recall:    0.7235
#   Samples:   264
# notumor:
#   Precision: 0.9139
#   Recall:    0.9565
#   Samples:   322
# pituitary:
#   Precision: 0.8836
#   Recall:    0.9525
#   Samples:   295
#
# ================================================================================
#
# Epoch 3/50 - Train Loss: 0.5279 - Train Acc: 81.13% - Val Loss: 0.3647 - Val Acc: 88.45% - Precision: 0.8849 - Recall: 0.8845 - F1-score: 0.8832
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9386
#   Recall:    0.8168
#   Samples:   262
# meningioma:
#   Precision: 0.7829
#   Recall:    0.7652
#   Samples:   264
# notumor:
#   Precision: 0.9041
#   Recall:    0.9658
#   Samples:   322
# pituitary:
#   Precision: 0.9073
#   Recall:    0.9627
#   Samples:   295
#
# ================================================================================
#
# Epoch 4/50 - Train Loss: 0.4778 - Train Acc: 82.29% - Val Loss: 0.3344 - Val Acc: 89.33% - Precision: 0.8915 - Recall: 0.8933 - F1-score: 0.8918
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.8898
#   Recall:    0.8626
#   Samples:   262
# meningioma:
#   Precision: 0.8097
#   Recall:    0.7576
#   Samples:   264
# notumor:
#   Precision: 0.9133
#   Recall:    0.9814
#   Samples:   322
# pituitary:
#   Precision: 0.9426
#   Recall:    0.9458
#   Samples:   295
#
# ================================================================================
#
# Epoch 5/50 - Train Loss: 0.4368 - Train Acc: 83.98% - Val Loss: 0.3179 - Val Acc: 89.68% - Precision: 0.8986 - Recall: 0.8968 - F1-score: 0.8954
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9727
#   Recall:    0.8168
#   Samples:   262
# meningioma:
#   Precision: 0.8093
#   Recall:    0.7879
#   Samples:   264
# notumor:
#   Precision: 0.9052
#   Recall:    0.9783
#   Samples:   322
# pituitary:
#   Precision: 0.9057
#   Recall:    0.9763
#   Samples:   295
#
# ================================================================================
#
# Epoch 6/50 - Train Loss: 0.4185 - Train Acc: 85.12% - Val Loss: 0.2843 - Val Acc: 89.94% - Precision: 0.8979 - Recall: 0.8994 - F1-score: 0.8969
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.8732
#   Recall:    0.9198
#   Samples:   262
# meningioma:
#   Precision: 0.8649
#   Recall:    0.7273
#   Samples:   264
# notumor:
#   Precision: 0.9201
#   Recall:    0.9658
#   Samples:   322
# pituitary:
#   Precision: 0.9251
#   Recall:    0.9627
#   Samples:   295
#
# ================================================================================
#
# Epoch 7/50 - Train Loss: 0.4038 - Train Acc: 85.01% - Val Loss: 0.2698 - Val Acc: 91.25% - Precision: 0.9121 - Recall: 0.9125 - F1-score: 0.9102
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9125
#   Recall:    0.9160
#   Samples:   262
# meningioma:
#   Precision: 0.9005
#   Recall:    0.7538
#   Samples:   264
# notumor:
#   Precision: 0.9062
#   Recall:    0.9907
#   Samples:   322
# pituitary:
#   Precision: 0.9283
#   Recall:    0.9661
#   Samples:   295
#
# ================================================================================
#
# Epoch 8/50 - Train Loss: 0.3709 - Train Acc: 87.11% - Val Loss: 0.2420 - Val Acc: 92.74% - Precision: 0.9278 - Recall: 0.9274 - F1-score: 0.9265
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9792
#   Recall:    0.8969
#   Samples:   262
# meningioma:
#   Precision: 0.8790
#   Recall:    0.8258
#   Samples:   264
# notumor:
#   Precision: 0.9351
#   Recall:    0.9845
#   Samples:   322
# pituitary:
#   Precision: 0.9177
#   Recall:    0.9831
#   Samples:   295
#
# ================================================================================
#
# Epoch 9/50 - Train Loss: 0.3525 - Train Acc: 87.28% - Val Loss: 0.2422 - Val Acc: 91.43% - Precision: 0.9145 - Recall: 0.9143 - F1-score: 0.9135
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9576
#   Recall:    0.8626
#   Samples:   262
# meningioma:
#   Precision: 0.8340
#   Recall:    0.8182
#   Samples:   264
# notumor:
#   Precision: 0.9431
#   Recall:    0.9783
#   Samples:   322
# pituitary:
#   Precision: 0.9172
#   Recall:    0.9763
#   Samples:   295
#
# ================================================================================
#
# Epoch 10/50 - Train Loss: 0.3575 - Train Acc: 87.00% - Val Loss: 0.2388 - Val Acc: 92.39% - Precision: 0.9251 - Recall: 0.9239 - F1-score: 0.9232
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9740
#   Recall:    0.8588
#   Samples:   262
# meningioma:
#   Precision: 0.8517
#   Recall:    0.8485
#   Samples:   264
# notumor:
#   Precision: 0.9198
#   Recall:    0.9969
#   Samples:   322
# pituitary:
#   Precision: 0.9533
#   Recall:    0.9695
#   Samples:   295
#
# ================================================================================
#
# Epoch 11/50 - Train Loss: 0.3421 - Train Acc: 87.79% - Val Loss: 0.2268 - Val Acc: 92.04% - Precision: 0.9206 - Recall: 0.9204 - F1-score: 0.9194
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9628
#   Recall:    0.8893
#   Samples:   262
# meningioma:
#   Precision: 0.8589
#   Recall:    0.8068
#   Samples:   264
# notumor:
#   Precision: 0.9573
#   Recall:    0.9752
#   Samples:   322
# pituitary:
#   Precision: 0.8985
#   Recall:    0.9898
#   Samples:   295
#
# ================================================================================
#
# Epoch 12/50 - Train Loss: 0.3422 - Train Acc: 87.33% - Val Loss: 0.2151 - Val Acc: 93.00% - Precision: 0.9293 - Recall: 0.9300 - F1-score: 0.9290
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9520
#   Recall:    0.9084
#   Samples:   262
# meningioma:
#   Precision: 0.8826
#   Recall:    0.8258
#   Samples:   264
# notumor:
#   Precision: 0.9438
#   Recall:    0.9907
#   Samples:   322
# pituitary:
#   Precision: 0.9351
#   Recall:    0.9763
#   Samples:   295
#
# ================================================================================
#
# Epoch 13/50 - Train Loss: 0.3016 - Train Acc: 89.21% - Val Loss: 0.1923 - Val Acc: 93.35% - Precision: 0.9344 - Recall: 0.9335 - F1-score: 0.9330
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9744
#   Recall:    0.8702
#   Samples:   262
# meningioma:
#   Precision: 0.8614
#   Recall:    0.8712
#   Samples:   264
# notumor:
#   Precision: 0.9467
#   Recall:    0.9938
#   Samples:   322
# pituitary:
#   Precision: 0.9507
#   Recall:    0.9797
#   Samples:   295
#
# ================================================================================
#
# Epoch 14/50 - Train Loss: 0.3028 - Train Acc: 88.82% - Val Loss: 0.1929 - Val Acc: 93.18% - Precision: 0.9316 - Recall: 0.9318 - F1-score: 0.9313
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9637
#   Recall:    0.9122
#   Samples:   262
# meningioma:
#   Precision: 0.8750
#   Recall:    0.8485
#   Samples:   264
# notumor:
#   Precision: 0.9548
#   Recall:    0.9845
#   Samples:   322
# pituitary:
#   Precision: 0.9283
#   Recall:    0.9661
#   Samples:   295
#
# ================================================================================
#
# Epoch 15/50 - Train Loss: 0.3164 - Train Acc: 88.44% - Val Loss: 0.1867 - Val Acc: 93.88% - Precision: 0.9383 - Recall: 0.9388 - F1-score: 0.9383
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9570
#   Recall:    0.9351
#   Samples:   262
# meningioma:
#   Precision: 0.8972
#   Recall:    0.8598
#   Samples:   264
# notumor:
#   Precision: 0.9545
#   Recall:    0.9783
#   Samples:   322
# pituitary:
#   Precision: 0.9408
#   Recall:    0.9695
#   Samples:   295
#
# ================================================================================
#
# Epoch 16/50 - Train Loss: 0.2977 - Train Acc: 89.67% - Val Loss: 0.1734 - Val Acc: 93.61% - Precision: 0.9361 - Recall: 0.9361 - F1-score: 0.9356
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9597
#   Recall:    0.9084
#   Samples:   262
# meningioma:
#   Precision: 0.8933
#   Recall:    0.8561
#   Samples:   264
# notumor:
#   Precision: 0.9632
#   Recall:    0.9752
#   Samples:   322
# pituitary:
#   Precision: 0.9241
#   Recall:    0.9898
#   Samples:   295
#
# ================================================================================
#
# Epoch 17/50 - Train Loss: 0.2857 - Train Acc: 89.54% - Val Loss: 0.1741 - Val Acc: 94.05% - Precision: 0.9400 - Recall: 0.9405 - F1-score: 0.9399
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9570
#   Recall:    0.9351
#   Samples:   262
# meningioma:
#   Precision: 0.9073
#   Recall:    0.8523
#   Samples:   264
# notumor:
#   Precision: 0.9518
#   Recall:    0.9814
#   Samples:   322
# pituitary:
#   Precision: 0.9414
#   Recall:    0.9797
#   Samples:   295
#
# ================================================================================
#
# Epoch 18/50 - Train Loss: 0.2798 - Train Acc: 90.22% - Val Loss: 0.1708 - Val Acc: 94.23% - Precision: 0.9432 - Recall: 0.9423 - F1-score: 0.9421
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9749
#   Recall:    0.8893
#   Samples:   262
# meningioma:
#   Precision: 0.8736
#   Recall:    0.8902
#   Samples:   264
# notumor:
#   Precision: 0.9785
#   Recall:    0.9876
#   Samples:   322
# pituitary:
#   Precision: 0.9387
#   Recall:    0.9864
#   Samples:   295
#
# ================================================================================
#
# Epoch 19/50 - Train Loss: 0.2801 - Train Acc: 89.89% - Val Loss: 0.1667 - Val Acc: 93.70% - Precision: 0.9391 - Recall: 0.9370 - F1-score: 0.9373
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9747
#   Recall:    0.8817
#   Samples:   262
# meningioma:
#   Precision: 0.8475
#   Recall:    0.9053
#   Samples:   264
# notumor:
#   Precision: 0.9723
#   Recall:    0.9814
#   Samples:   322
# pituitary:
#   Precision: 0.9532
#   Recall:    0.9661
#   Samples:   295
#
# ================================================================================
#
# Epoch 20/50 - Train Loss: 0.2737 - Train Acc: 90.57% - Val Loss: 0.1594 - Val Acc: 94.23% - Precision: 0.9419 - Recall: 0.9423 - F1-score: 0.9420
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9280
#   Recall:    0.9351
#   Samples:   262
# meningioma:
#   Precision: 0.8984
#   Recall:    0.8712
#   Samples:   264
# notumor:
#   Precision: 0.9754
#   Recall:    0.9845
#   Samples:   322
# pituitary:
#   Precision: 0.9564
#   Recall:    0.9661
#   Samples:   295
#
# ================================================================================
#
# Epoch 21/50 - Train Loss: 0.2690 - Train Acc: 90.41% - Val Loss: 0.1616 - Val Acc: 93.96% - Precision: 0.9411 - Recall: 0.9396 - F1-score: 0.9395
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9872
#   Recall:    0.8817
#   Samples:   262
# meningioma:
#   Precision: 0.8676
#   Recall:    0.8939
#   Samples:   264
# notumor:
#   Precision: 0.9667
#   Recall:    0.9907
#   Samples:   322
# pituitary:
#   Precision: 0.9381
#   Recall:    0.9763
#   Samples:   295
#
# ================================================================================
#
# Epoch 22/50 - Train Loss: 0.2539 - Train Acc: 90.96% - Val Loss: 0.1401 - Val Acc: 94.66% - Precision: 0.9467 - Recall: 0.9466 - F1-score: 0.9466
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9603
#   Recall:    0.9237
#   Samples:   262
# meningioma:
#   Precision: 0.8906
#   Recall:    0.8939
#   Samples:   264
# notumor:
#   Precision: 0.9753
#   Recall:    0.9814
#   Samples:   322
# pituitary:
#   Precision: 0.9536
#   Recall:    0.9763
#   Samples:   295
#
# ================================================================================
#
# Epoch 23/50 - Train Loss: 0.2569 - Train Acc: 90.90% - Val Loss: 0.1503 - Val Acc: 94.93% - Precision: 0.9493 - Recall: 0.9493 - F1-score: 0.9487
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9341
#   Recall:    0.9733
#   Samples:   262
# meningioma:
#   Precision: 0.9419
#   Recall:    0.8598
#   Samples:   264
# notumor:
#   Precision: 0.9752
#   Recall:    0.9783
#   Samples:   322
# pituitary:
#   Precision: 0.9412
#   Recall:    0.9763
#   Samples:   295
#
# ================================================================================
#
# Epoch 24/50 - Train Loss: 0.2509 - Train Acc: 91.11% - Val Loss: 0.1386 - Val Acc: 95.19% - Precision: 0.9517 - Recall: 0.9519 - F1-score: 0.9513
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9545
#   Recall:    0.9618
#   Samples:   262
# meningioma:
#   Precision: 0.9426
#   Recall:    0.8712
#   Samples:   264
# notumor:
#   Precision: 0.9639
#   Recall:    0.9938
#   Samples:   322
# pituitary:
#   Precision: 0.9439
#   Recall:    0.9695
#   Samples:   295
#
# ================================================================================
#
# Epoch 25/50 - Train Loss: 0.2433 - Train Acc: 91.29% - Val Loss: 0.1385 - Val Acc: 95.28% - Precision: 0.9527 - Recall: 0.9528 - F1-score: 0.9527
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9648
#   Recall:    0.9427
#   Samples:   262
# meningioma:
#   Precision: 0.9122
#   Recall:    0.9053
#   Samples:   264
# notumor:
#   Precision: 0.9755
#   Recall:    0.9876
#   Samples:   322
# pituitary:
#   Precision: 0.9532
#   Recall:    0.9661
#   Samples:   295
#
# ================================================================================
#
# Epoch 26/50 - Train Loss: 0.2485 - Train Acc: 90.68% - Val Loss: 0.1540 - Val Acc: 94.58% - Precision: 0.9457 - Recall: 0.9458 - F1-score: 0.9453
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9680
#   Recall:    0.9237
#   Samples:   262
# meningioma:
#   Precision: 0.9051
#   Recall:    0.8674
#   Samples:   264
# notumor:
#   Precision: 0.9726
#   Recall:    0.9907
#   Samples:   322
# pituitary:
#   Precision: 0.9327
#   Recall:    0.9864
#   Samples:   295
#
# ================================================================================
#
# Epoch 27/50 - Train Loss: 0.2312 - Train Acc: 91.55% - Val Loss: 0.1206 - Val Acc: 96.41% - Precision: 0.9641 - Recall: 0.9641 - F1-score: 0.9640
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9843
#   Recall:    0.9542
#   Samples:   262
# meningioma:
#   Precision: 0.9275
#   Recall:    0.9205
#   Samples:   264
# notumor:
#   Precision: 0.9755
#   Recall:    0.9907
#   Samples:   322
# pituitary:
#   Precision: 0.9667
#   Recall:    0.9831
#   Samples:   295
#
# ================================================================================
#
# Epoch 28/50 - Train Loss: 0.2163 - Train Acc: 92.62% - Val Loss: 0.1297 - Val Acc: 95.36% - Precision: 0.9544 - Recall: 0.9536 - F1-score: 0.9536
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9754
#   Recall:    0.9084
#   Samples:   262
# meningioma:
#   Precision: 0.8905
#   Recall:    0.9242
#   Samples:   264
# notumor:
#   Precision: 0.9786
#   Recall:    0.9938
#   Samples:   322
# pituitary:
#   Precision: 0.9664
#   Recall:    0.9763
#   Samples:   295
#
# ================================================================================
#
# Epoch 29/50 - Train Loss: 0.2200 - Train Acc: 92.27% - Val Loss: 0.1284 - Val Acc: 96.24% - Precision: 0.9626 - Recall: 0.9624 - F1-score: 0.9623
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9880
#   Recall:    0.9427
#   Samples:   262
# meningioma:
#   Precision: 0.9242
#   Recall:    0.9242
#   Samples:   264
# notumor:
#   Precision: 0.9785
#   Recall:    0.9876
#   Samples:   322
# pituitary:
#   Precision: 0.9572
#   Recall:    0.9864
#   Samples:   295
#
# ================================================================================
#
# Epoch 30/50 - Train Loss: 0.2240 - Train Acc: 91.77% - Val Loss: 0.1195 - Val Acc: 95.89% - Precision: 0.9588 - Recall: 0.9589 - F1-score: 0.9585
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9513
#   Recall:    0.9695
#   Samples:   262
# meningioma:
#   Precision: 0.9476
#   Recall:    0.8902
#   Samples:   264
# notumor:
#   Precision: 0.9815
#   Recall:    0.9876
#   Samples:   322
# pituitary:
#   Precision: 0.9507
#   Recall:    0.9797
#   Samples:   295
#
# ================================================================================
#
# Epoch 31/50 - Train Loss: 0.2097 - Train Acc: 92.69% - Val Loss: 0.1427 - Val Acc: 95.10% - Precision: 0.9511 - Recall: 0.9510 - F1-score: 0.9508
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9472
#   Recall:    0.9580
#   Samples:   262
# meningioma:
#   Precision: 0.9283
#   Recall:    0.8826
#   Samples:   264
# notumor:
#   Precision: 0.9874
#   Recall:    0.9752
#   Samples:   322
# pituitary:
#   Precision: 0.9353
#   Recall:    0.9797
#   Samples:   295
#
# ================================================================================
#
# Epoch 32/50 - Train Loss: 0.2240 - Train Acc: 91.57% - Val Loss: 0.1246 - Val Acc: 95.98% - Precision: 0.9599 - Recall: 0.9598 - F1-score: 0.9596
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9880
#   Recall:    0.9466
#   Samples:   262
# meningioma:
#   Precision: 0.9264
#   Recall:    0.9053
#   Samples:   264
# notumor:
#   Precision: 0.9755
#   Recall:    0.9907
#   Samples:   322
# pituitary:
#   Precision: 0.9479
#   Recall:    0.9864
#   Samples:   295
#
# ================================================================================
#
# Epoch 33/50 - Train Loss: 0.2103 - Train Acc: 92.45% - Val Loss: 0.1114 - Val Acc: 96.15% - Precision: 0.9613 - Recall: 0.9615 - F1-score: 0.9611
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9695
#   Recall:    0.9695
#   Samples:   262
# meningioma:
#   Precision: 0.9516
#   Recall:    0.8939
#   Samples:   264
# notumor:
#   Precision: 0.9640
#   Recall:    0.9969
#   Samples:   322
# pituitary:
#   Precision: 0.9600
#   Recall:    0.9763
#   Samples:   295
#
# ================================================================================
#
# Epoch 34/50 - Train Loss: 0.2169 - Train Acc: 92.32% - Val Loss: 0.1426 - Val Acc: 94.14% - Precision: 0.9420 - Recall: 0.9414 - F1-score: 0.9404
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9104
#   Recall:    0.9695
#   Samples:   262
# meningioma:
#   Precision: 0.9353
#   Recall:    0.8220
#   Samples:   264
# notumor:
#   Precision: 0.9875
#   Recall:    0.9814
#   Samples:   322
# pituitary:
#   Precision: 0.9263
#   Recall:    0.9797
#   Samples:   295
#
# ================================================================================
#
# Epoch 35/50 - Train Loss: 0.2107 - Train Acc: 92.60% - Val Loss: 0.1133 - Val Acc: 95.89% - Precision: 0.9587 - Recall: 0.9589 - F1-score: 0.9587
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9538
#   Recall:    0.9466
#   Samples:   262
# meningioma:
#   Precision: 0.9231
#   Recall:    0.9091
#   Samples:   264
# notumor:
#   Precision: 0.9815
#   Recall:    0.9907
#   Samples:   322
# pituitary:
#   Precision: 0.9698
#   Recall:    0.9797
#   Samples:   295
#
# ================================================================================
#
# Epoch 36/50 - Train Loss: 0.1984 - Train Acc: 92.84% - Val Loss: 0.1204 - Val Acc: 95.63% - Precision: 0.9566 - Recall: 0.9563 - F1-score: 0.9558
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9275
#   Recall:    0.9771
#   Samples:   262
# meningioma:
#   Precision: 0.9585
#   Recall:    0.8750
#   Samples:   264
# notumor:
#   Precision: 0.9786
#   Recall:    0.9938
#   Samples:   322
# pituitary:
#   Precision: 0.9565
#   Recall:    0.9695
#   Samples:   295
#
# ================================================================================
#
# Epoch 37/50 - Train Loss: 0.1945 - Train Acc: 93.00% - Val Loss: 0.1090 - Val Acc: 96.24% - Precision: 0.9622 - Recall: 0.9624 - F1-score: 0.9622
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9690
#   Recall:    0.9542
#   Samples:   262
# meningioma:
#   Precision: 0.9375
#   Recall:    0.9091
#   Samples:   264
# notumor:
#   Precision: 0.9787
#   Recall:    0.9969
#   Samples:   322
# pituitary:
#   Precision: 0.9601
#   Recall:    0.9797
#   Samples:   295
#
# ================================================================================
#
# Epoch 38/50 - Train Loss: 0.1958 - Train Acc: 93.13% - Val Loss: 0.1131 - Val Acc: 95.54% - Precision: 0.9553 - Recall: 0.9554 - F1-score: 0.9552
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9653
#   Recall:    0.9542
#   Samples:   262
# meningioma:
#   Precision: 0.9219
#   Recall:    0.8939
#   Samples:   264
# notumor:
#   Precision: 0.9845
#   Recall:    0.9845
#   Samples:   322
# pituitary:
#   Precision: 0.9444
#   Recall:    0.9797
#   Samples:   295
#
# ================================================================================
#
# Epoch 39/50 - Train Loss: 0.1987 - Train Acc: 92.86% - Val Loss: 0.1028 - Val Acc: 96.76% - Precision: 0.9676 - Recall: 0.9676 - F1-score: 0.9676
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9693
#   Recall:    0.9656
#   Samples:   262
# meningioma:
#   Precision: 0.9392
#   Recall:    0.9356
#   Samples:   264
# notumor:
#   Precision: 0.9876
#   Recall:    0.9876
#   Samples:   322
# pituitary:
#   Precision: 0.9697
#   Recall:    0.9763
#   Samples:   295
#
# ================================================================================
#
# Epoch 40/50 - Train Loss: 0.1781 - Train Acc: 93.46% - Val Loss: 0.1365 - Val Acc: 94.84% - Precision: 0.9483 - Recall: 0.9484 - F1-score: 0.9479
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9643
#   Recall:    0.9275
#   Samples:   262
# meningioma:
#   Precision: 0.9203
#   Recall:    0.8750
#   Samples:   264
# notumor:
#   Precision: 0.9726
#   Recall:    0.9938
#   Samples:   322
# pituitary:
#   Precision: 0.9325
#   Recall:    0.9831
#   Samples:   295
#
# ================================================================================
#
# Epoch 41/50 - Train Loss: 0.1757 - Train Acc: 93.67% - Val Loss: 0.1025 - Val Acc: 96.24% - Precision: 0.9624 - Recall: 0.9624 - F1-score: 0.9623
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9727
#   Recall:    0.9504
#   Samples:   262
# meningioma:
#   Precision: 0.9316
#   Recall:    0.9280
#   Samples:   264
# notumor:
#   Precision: 0.9815
#   Recall:    0.9876
#   Samples:   322
# pituitary:
#   Precision: 0.9600
#   Recall:    0.9763
#   Samples:   295
#
# ================================================================================
#
# Epoch 42/50 - Train Loss: 0.1853 - Train Acc: 93.50% - Val Loss: 0.1113 - Val Acc: 96.24% - Precision: 0.9623 - Recall: 0.9624 - F1-score: 0.9619
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9551
#   Recall:    0.9733
#   Samples:   262
# meningioma:
#   Precision: 0.9590
#   Recall:    0.8864
#   Samples:   264
# notumor:
#   Precision: 0.9756
#   Recall:    0.9938
#   Samples:   322
# pituitary:
#   Precision: 0.9572
#   Recall:    0.9864
#   Samples:   295
#
# ================================================================================
#
# Epoch 43/50 - Train Loss: 0.1756 - Train Acc: 93.92% - Val Loss: 0.1037 - Val Acc: 95.89% - Precision: 0.9586 - Recall: 0.9589 - F1-score: 0.9587
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9396
#   Recall:    0.9504
#   Samples:   262
# meningioma:
#   Precision: 0.9294
#   Recall:    0.8977
#   Samples:   264
# notumor:
#   Precision: 0.9907
#   Recall:    0.9938
#   Samples:   322
# pituitary:
#   Precision: 0.9667
#   Recall:    0.9831
#   Samples:   295
#
# ================================================================================
#
# Epoch 44/50 - Train Loss: 0.1762 - Train Acc: 93.96% - Val Loss: 0.0933 - Val Acc: 96.76% - Precision: 0.9678 - Recall: 0.9676 - F1-score: 0.9677
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9843
#   Recall:    0.9542
#   Samples:   262
# meningioma:
#   Precision: 0.9291
#   Recall:    0.9432
#   Samples:   264
# notumor:
#   Precision: 0.9846
#   Recall:    0.9907
#   Samples:   322
# pituitary:
#   Precision: 0.9697
#   Recall:    0.9763
#   Samples:   295
#
# ================================================================================
#
# Epoch 45/50 - Train Loss: 0.1772 - Train Acc: 93.89% - Val Loss: 0.1089 - Val Acc: 95.98% - Precision: 0.9598 - Recall: 0.9598 - F1-score: 0.9595
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9799
#   Recall:    0.9313
#   Samples:   262
# meningioma:
#   Precision: 0.9300
#   Recall:    0.9053
#   Samples:   264
# notumor:
#   Precision: 0.9787
#   Recall:    0.9969
#   Samples:   322
# pituitary:
#   Precision: 0.9482
#   Recall:    0.9932
#   Samples:   295
#
# ================================================================================
#
# Epoch 46/50 - Train Loss: 0.1772 - Train Acc: 93.54% - Val Loss: 0.1159 - Val Acc: 95.98% - Precision: 0.9601 - Recall: 0.9598 - F1-score: 0.9598
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9761
#   Recall:    0.9351
#   Samples:   262
# meningioma:
#   Precision: 0.9111
#   Recall:    0.9318
#   Samples:   264
# notumor:
#   Precision: 0.9755
#   Recall:    0.9907
#   Samples:   322
# pituitary:
#   Precision: 0.9729
#   Recall:    0.9729
#   Samples:   295
#
# ================================================================================
#
# Epoch 47/50 - Train Loss: 0.1742 - Train Acc: 93.96% - Val Loss: 0.0970 - Val Acc: 96.76% - Precision: 0.9679 - Recall: 0.9676 - F1-score: 0.9676
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9841
#   Recall:    0.9427
#   Samples:   262
# meningioma:
#   Precision: 0.9291
#   Recall:    0.9432
#   Samples:   264
# notumor:
#   Precision: 0.9786
#   Recall:    0.9938
#   Samples:   322
# pituitary:
#   Precision: 0.9764
#   Recall:    0.9831
#   Samples:   295
#
# ================================================================================
#
# Epoch 48/50 - Train Loss: 0.1597 - Train Acc: 94.20% - Val Loss: 0.1083 - Val Acc: 96.50% - Precision: 0.9649 - Recall: 0.9650 - F1-score: 0.9649
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9583
#   Recall:    0.9656
#   Samples:   262
# meningioma:
#   Precision: 0.9421
#   Recall:    0.9242
#   Samples:   264
# notumor:
#   Precision: 0.9876
#   Recall:    0.9876
#   Samples:   322
# pituitary:
#   Precision: 0.9664
#   Recall:    0.9763
#   Samples:   295
#
# ================================================================================
#
# Epoch 49/50 - Train Loss: 0.1660 - Train Acc: 94.13% - Val Loss: 0.1041 - Val Acc: 96.68% - Precision: 0.9669 - Recall: 0.9668 - F1-score: 0.9667
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9802
#   Recall:    0.9427
#   Samples:   262
# meningioma:
#   Precision: 0.9321
#   Recall:    0.9356
#   Samples:   264
# notumor:
#   Precision: 0.9877
#   Recall:    0.9938
#   Samples:   322
# pituitary:
#   Precision: 0.9636
#   Recall:    0.9864
#   Samples:   295
#
# ================================================================================
#
# Epoch 50/50 - Train Loss: 0.1702 - Train Acc: 93.74% - Val Loss: 0.1137 - Val Acc: 96.06% - Precision: 0.9609 - Recall: 0.9606 - F1-score: 0.9600
#
# Class-wise Validation Metrics:
# glioma:
#   Precision: 0.9591
#   Recall:    0.9847
#   Samples:   262
# meningioma:
#   Precision: 0.9705
#   Recall:    0.8712
#   Samples:   264
# notumor:
#   Precision: 0.9610
#   Recall:    0.9938
#   Samples:   322
# pituitary:
#   Precision: 0.9539
#   Recall:    0.9831
#   Samples:   295
#
# ================================================================================
#
# Class Weights: {0: 1.080999242997729, 1: 1.0664675130694548, 2: 0.8952978056426333, 3: 0.9800960878517502}

# %%
torch.save(model, "brain_tumor_model.pth")
